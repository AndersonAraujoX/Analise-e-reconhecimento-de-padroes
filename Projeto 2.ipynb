# %%
x1=[]
x2=[]
x3=[]
x4=[]
for line in open('iris.date','r'):
    values=[s for s in line.split()]
    x1.append(values[0])
    x2.append(values[1])
plt.plot(x1,x2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-cf8a895ed4bd> in <module>
#       3 x3=[]
#       4 x4=[]
# ----> 5 for line in open('iris.date','r'):
#       6     values=[s for s in line.split()]
#       7     x1.append(values[0])
#
# FileNotFoundError: [Errno 2] No such file or directory: 'iris.date'
